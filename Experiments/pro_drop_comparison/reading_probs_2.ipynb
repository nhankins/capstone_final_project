# %%
import pandas as pd

# %%
with open("en_gum-ud_en_gum-ud-test.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df = pd.DataFrame([sub.split(",") for sub in read_file])
df.head(20)
df.to_csv('english_on_english.csv', sep=',')
# Out:
# <class 'list'>

# %%
filtered_df = df[[1,7,8,9,10,11]]
display(filtered_df)
# Out:
#          1               7                      8      9   \
# 0      role  predicted_role          probability_A  layer
# 1         A               A     0.9997984766960144     12
# 2         O               O  2.213086645497242e-06     12
# 3         A               A     0.9523512721061707     12
# 4         O               O   0.007723919115960598     12
# ...     ...             ...                    ...    ...
# 16142     O               O    0.11322041600942612      0
# 16143     O               A     0.9858797192573547      0
# 16144     A               A     0.9999995231628418      0
# 16145     O               A     0.9999344348907471      0
# 16146     O               O      0.463773638010025      0
#
#                            10                        11
# 0      source_test_accuracy_A  source_test_accuracy_O\n
# 1          0.9609756097560975      0.8592896174863388\n
# 2          0.9609756097560975      0.8592896174863388\n
# 3          0.9609756097560975      0.8592896174863388\n
# 4          0.9609756097560975      0.8592896174863388\n
# ...                       ...                       ...
# 16142      0.7902439024390244      0.6653005464480874\n
# 16143      0.7902439024390244      0.6653005464480874\n
# 16144      0.7902439024390244      0.6653005464480874\n
# 16145      0.7902439024390244      0.6653005464480874\n
# 16146      0.7902439024390244      0.6653005464480874\n
#
# [16147 rows x 6 columns]

# %%
only_S = filtered_df.loc[filtered_df[1] == 'S']
display(only_S)
# Out:
#       1  7                    8   9                   10                    11
# 10     S  A   0.9825294017791748  12  0.9609756097560975  0.8592896174863388\n
# 21     S  O  0.08884982019662857  12  0.9609756097560975  0.8592896174863388\n
# 22     S  A   0.9969292283058167  12  0.9609756097560975  0.8592896174863388\n
# 26     S  A   0.9850608706474304  12  0.9609756097560975  0.8592896174863388\n
# 39     S  A   0.9999465942382812  12  0.9609756097560975  0.8592896174863388\n
# ...   .. ..                  ...  ..                 ...                   ...
# 16097  S  A   0.9388505220413208   0  0.7902439024390244  0.6653005464480874\n
# 16098  S  A   0.9999971389770508   0  0.7902439024390244  0.6653005464480874\n
# 16099  S  A   0.9999344348907471   0  0.7902439024390244  0.6653005464480874\n
# 16117  S  A                  1.0   0  0.7902439024390244  0.6653005464480874\n
# 16120  S  A                  1.0   0  0.7902439024390244  0.6653005464480874\n
#
# [2301 rows x 6 columns]

# %%
obj_col = only_S.loc[only_S[7] == 'O']
display(obj_col)
# Out:
#       1  7                      8   9                   10  \
# 21     S  O    0.08884982019662857  12  0.9609756097560975
# 223    S  O    0.16394346952438354  12  0.9609756097560975
# 594    S  O     0.3837601840496063  12  0.9609756097560975
# 680    S  O    0.12068461626768112  12  0.9609756097560975
# 768    S  O    0.13339489698410034  12  0.9609756097560975
# ...   .. ..                    ...  ..                 ...
# 15973  S  O  0.0025200059171766043   0  0.7902439024390244
# 15976  S  O     0.4531935155391693   0  0.7902439024390244
# 15983  S  O    0.09708137065172195   0  0.7902439024390244
# 16048  S  O     0.1845359057188034   0  0.7902439024390244
# 16056  S  O    0.11252248287200928   0  0.7902439024390244
#
#                          11
# 21     0.8592896174863388\n
# 223    0.8592896174863388\n
# 594    0.8592896174863388\n
# 680    0.8592896174863388\n
# 768    0.8592896174863388\n
# ...                     ...
# 15973  0.6653005464480874\n
# 15976  0.6653005464480874\n
# 15983  0.6653005464480874\n
# 16048  0.6653005464480874\n
# 16056  0.6653005464480874\n
#
# [248 rows x 6 columns]

# %%
agent_col = only_S.loc[only_S[7] == 'A']
display(agent_col)
# Out:
#       1  7                   8   9                   10                    11
# 10     S  A  0.9825294017791748  12  0.9609756097560975  0.8592896174863388\n
# 22     S  A  0.9969292283058167  12  0.9609756097560975  0.8592896174863388\n
# 26     S  A  0.9850608706474304  12  0.9609756097560975  0.8592896174863388\n
# 39     S  A  0.9999465942382812  12  0.9609756097560975  0.8592896174863388\n
# 43     S  A  0.9999995231628418  12  0.9609756097560975  0.8592896174863388\n
# ...   .. ..                 ...  ..                 ...                   ...
# 16097  S  A  0.9388505220413208   0  0.7902439024390244  0.6653005464480874\n
# 16098  S  A  0.9999971389770508   0  0.7902439024390244  0.6653005464480874\n
# 16099  S  A  0.9999344348907471   0  0.7902439024390244  0.6653005464480874\n
# 16117  S  A                 1.0   0  0.7902439024390244  0.6653005464480874\n
# 16120  S  A                 1.0   0  0.7902439024390244  0.6653005464480874\n
#
# [2053 rows x 6 columns]

# %%
### Returns the SA and SO averages of Probability A column for each layer

layer12 = only_S[only_S[9]== '12']
#display(layer12)
layer12[8] = pd.to_numeric(layer12[8], downcast="float")
print(layer12[8].mean())

layer11 = only_S[only_S[9]== '11']
#display(layer11)
layer11[8] = pd.to_numeric(layer11[8], downcast="float")
print(layer11[8].mean())

layer10 = only_S[only_S[9]== '10']
#display(layer10)
layer10[8] = pd.to_numeric(layer10[8], downcast="float")
print(layer10[8].mean())

layer9 = only_S[only_S[9]== '9']
#display(layer9)
layer9[8] = pd.to_numeric(layer9[8], downcast="float")
print(layer9[8].mean())

layer8 = only_S[only_S[9]== '8']
#display(layer8)
layer8[8] = pd.to_numeric(layer8[8], downcast="float")
print(layer8[8].mean())

layer7 = only_S[only_S[9]== '7']
#display(layer7)
layer7[8] = pd.to_numeric(layer7[8], downcast="float")
print(layer7[8].mean())

layer6 = only_S[only_S[9]== '6']
#display(layer6)
layer6[8] = pd.to_numeric(layer6[8], downcast="float")
print(layer6[8].mean())

layer5 = only_S[only_S[9]== '5']
#display(layer10)
layer5[8] = pd.to_numeric(layer5[8], downcast="float")
print(layer5[8].mean())

layer4 = only_S[only_S[9]== '4']
#display(layer9)
layer4[8] = pd.to_numeric(layer4[8], downcast="float")
print(layer4[8].mean())

layer3 = only_S[only_S[9]== '3']
#display(layer8)
layer3[8] = pd.to_numeric(layer3[8], downcast="float")
print(layer3[8].mean())

layer2 = only_S[only_S[9]== '2']
#display(layer7)
layer2[8] = pd.to_numeric(layer2[8], downcast="float")
print(layer2[8].mean())

layer1 = only_S[only_S[9]== '1']
#display(layer6)
layer1[8] = pd.to_numeric(layer1[8], downcast="float")
print(layer1[8].mean())

layer0 = only_S[only_S[9]== '0']
#display(layer6)
layer0[8] = pd.to_numeric(layer0[8], downcast="float")
print(layer0[8].mean())
# Out:
# 0.9273116
# 0.9585842
# 0.96644473
# 0.9639663
# 0.95213085
# 0.94739634
# 0.95023894
# 0.9252806
# 0.889561
# 0.856487
# 0.76526386
# 0.67756736
# 0.69192797
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/1109710783.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer12[8] = pd.to_numeric(layer12[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/1109710783.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer11[8] = pd.to_numeric(layer11[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/1109710783.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer10[8] = pd.to_numeric(layer10[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/1109710783.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer9[8] = pd.to_numeric(layer9[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/1109710783.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer8[8] = pd.to_numeric(layer8[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/1109710783.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer7[8] = pd.to_numeric(layer7[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/1109710783.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer6[8] = pd.to_numeric(layer6[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/1109710783.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer5[8] = pd.to_numeric(layer5[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/1109710783.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer4[8] = pd.to_numeric(layer4[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/1109710783.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer3[8] = pd.to_numeric(layer3[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/1109710783.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer2[8] = pd.to_numeric(layer2[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/1109710783.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer1[8] = pd.to_numeric(layer1[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/1109710783.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer0[8] = pd.to_numeric(layer0[8], downcast="float")

# %%
### Returns the SA averages of Probability A column for each layer

layer12_agent = agent_col[agent_col[9]== '12']
#display(layer12_agent)
layer12_agent[8] = pd.to_numeric(layer12_agent[8], downcast="float")
print(layer12_agent[8].mean())

layer11_agent = agent_col[agent_col[9]== '11']
#display(layer11_agent)
layer11_agent[8] = pd.to_numeric(layer11_agent[8], downcast="float")
print(layer11_agent[8].mean())

layer10_agent = agent_col[agent_col[9]== '10']
#display(layer10_agent)
layer10_agent[8] = pd.to_numeric(layer10_agent[8], downcast="float")
print(layer10_agent[8].mean())

layer9_agent = agent_col[agent_col[9]== '9']
#display(layer9_agent)
layer9_agent[8] = pd.to_numeric(layer9_agent[8], downcast="float")
print(layer9_agent[8].mean())

layer8_agent = agent_col[agent_col[9]== '8']
#display(layer8_agent)
layer8_agent[8] = pd.to_numeric(layer8_agent[8], downcast="float")
print(layer8_agent[8].mean())

layer7_agent = agent_col[agent_col[9]== '7']
#display(layer7_agent)
layer7_agent[8] = pd.to_numeric(layer7_agent[8], downcast="float")
print(layer7_agent[8].mean())

layer6_agent = agent_col[agent_col[9]== '6']
#display(layer6_agent)
layer6_agent[8] = pd.to_numeric(layer6_agent[8], downcast="float")
print(layer6_agent[8].mean())

layer5_agent = agent_col[agent_col[9]== '5']
#display(layer10_agent)
layer5_agent[8] = pd.to_numeric(layer5_agent[8], downcast="float")
print(layer5_agent[8].mean())

layer4_agent = agent_col[agent_col[9]== '4']
#display(layer9_agent)
layer4_agent[8] = pd.to_numeric(layer4_agent[8], downcast="float")
print(layer4_agent[8].mean())

layer3_agent = agent_col[agent_col[9]== '3']
#display(layer8_agent)
layer3_agent[8] = pd.to_numeric(layer3_agent[8], downcast="float")
print(layer3_agent[8].mean())

layer2_agent = agent_col[agent_col[9]== '2']
#display(layer7_agent)
layer2_agent[8] = pd.to_numeric(layer2_agent[8], downcast="float")
print(layer2_agent[8].mean())

layer1_agent = agent_col[agent_col[9]== '1']
#display(layer6_agent)
layer1_agent[8] = pd.to_numeric(layer1_agent[8], downcast="float")
print(layer1_agent[8].mean())

layer0_agent = agent_col[agent_col[9]== '0']
#display(layer6_agent)
layer0_agent[8] = pd.to_numeric(layer0_agent[8], downcast="float")
print(layer0_agent[8].mean())
# Out:
# 0.98919606
# 0.9871955
# 0.9861695
# 0.9921879
# 0.98925257
# 0.9839307
# 0.99310684
# 0.98773474
# 0.9760698
# 0.96045786
# 0.92941487
# 0.919784
# 0.94780904
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/770741630.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer12_agent[8] = pd.to_numeric(layer12_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/770741630.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer11_agent[8] = pd.to_numeric(layer11_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/770741630.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer10_agent[8] = pd.to_numeric(layer10_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/770741630.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer9_agent[8] = pd.to_numeric(layer9_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/770741630.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer8_agent[8] = pd.to_numeric(layer8_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/770741630.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer7_agent[8] = pd.to_numeric(layer7_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/770741630.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer6_agent[8] = pd.to_numeric(layer6_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/770741630.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer5_agent[8] = pd.to_numeric(layer5_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/770741630.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer4_agent[8] = pd.to_numeric(layer4_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/770741630.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer3_agent[8] = pd.to_numeric(layer3_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/770741630.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer2_agent[8] = pd.to_numeric(layer2_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/770741630.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer1_agent[8] = pd.to_numeric(layer1_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/770741630.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer0_agent[8] = pd.to_numeric(layer0_agent[8], downcast="float")

# %%
### Returns the SO averages of Probability A column for each layer


layer12_obj = obj_col[obj_col[9]== '12']
#display(layer12_obj)
layer12_obj[8] = pd.to_numeric(layer12_obj[8], downcast="float")
print(layer12_obj[8].mean())

layer11_obj = obj_col[obj_col[9]== '11']
#display(layer11_obj)
layer11_obj[8] = pd.to_numeric(layer11_obj[8], downcast="float")
print(layer11_obj[8].mean())

layer10_obj = obj_col[obj_col[9]== '10']
#display(layer10_agent)
layer10_obj[8] = pd.to_numeric(layer10_obj[8], downcast="float")
print(layer10_obj[8].mean())

layer9_obj = obj_col[obj_col[9]== '9']
#display(layer9_agent)
layer9_obj[8] = pd.to_numeric(layer9_obj[8], downcast="float")
print(layer9_obj[8].mean())

layer8_obj = obj_col[obj_col[9]== '8']
#display(layer8_agent)
layer8_obj[8] = pd.to_numeric(layer8_obj[8], downcast="float")
print(layer8_obj[8].mean())

layer7_obj = obj_col[obj_col[9]== '7']
#display(layer7_agent)
layer7_obj[8] = pd.to_numeric(layer7_obj[8], downcast="float")
print(layer7_obj[8].mean())

layer6_obj = obj_col[obj_col[9]== '6']
#display(layer6_agent)
layer6_obj[8] = pd.to_numeric(layer6_obj[8], downcast="float")
print(layer6_obj[8].mean())

layer5_obj = obj_col[obj_col[9]== '5']
#display(layer10_agent)
layer5_obj[8] = pd.to_numeric(layer5_obj[8], downcast="float")
print(layer5_obj[8].mean())

layer4_obj = obj_col[obj_col[9]== '4']
#display(layer9_agent)
layer4_obj[8] = pd.to_numeric(layer4_obj[8], downcast="float")
print(layer4_obj[8].mean())

layer3_obj = obj_col[obj_col[9]== '3']
#display(layer8_agent)
layer3_obj[8] = pd.to_numeric(layer3_obj[8], downcast="float")
print(layer3_obj[8].mean())

layer2_obj = obj_col[obj_col[9]== '2']
#display(layer7_agent)
layer2_obj[8] = pd.to_numeric(layer2_obj[8], downcast="float")
print(layer2_obj[8].mean())

layer1_obj = obj_col[obj_col[9]== '1']
#display(layer6_agent)
layer1_obj[8] = pd.to_numeric(layer1_obj[8], downcast="float")
print(layer1_obj[8].mean())

layer0_obj = obj_col[obj_col[9]== '0']
#display(layer6_agent)
layer0_obj[8] = pd.to_numeric(layer0_obj[8], downcast="float")
print(layer0_obj[8].mean())
# Out:
# 0.14661556
# 0.14316566
# 0.113344856
# 0.15965077
# 0.16793492
# 0.06013367
# 0.044655304
# 0.13739745
# 0.07536024
# 0.123964004
# 0.09927975
# 0.12585175
# 0.12433722
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/730305013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer12_obj[8] = pd.to_numeric(layer12_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/730305013.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer11_obj[8] = pd.to_numeric(layer11_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/730305013.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer10_obj[8] = pd.to_numeric(layer10_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/730305013.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer9_obj[8] = pd.to_numeric(layer9_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/730305013.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer8_obj[8] = pd.to_numeric(layer8_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/730305013.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer7_obj[8] = pd.to_numeric(layer7_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/730305013.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer6_obj[8] = pd.to_numeric(layer6_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/730305013.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer5_obj[8] = pd.to_numeric(layer5_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/730305013.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer4_obj[8] = pd.to_numeric(layer4_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/730305013.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer3_obj[8] = pd.to_numeric(layer3_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/730305013.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer2_obj[8] = pd.to_numeric(layer2_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/730305013.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer1_obj[8] = pd.to_numeric(layer1_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_27760/730305013.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer0_obj[8] = pd.to_numeric(layer0_obj[8], downcast="float")
