# %%
import pandas as pd
#from extract import print_layers, add_to_df

# %%
# col_names = ["EngSA", "EngSO", "GerSA",	"GerSO","FreSA","FreSO","KorSA","KorSO","PorSA","PorSO","HebSA","HebSO"]
# df = pd.read_csv('trained_on_english.csv', names=col_names, encoding="ISO-8859-1")
# df.drop(index=[0], inplace=True)
# display(df)

# %%
## Split into pro-drop and non pro-drop for english
# pro_group = df.iloc[:,:6]
# non_pro_group = df.iloc[:,6:]
# display(pro_group)
# display(non_pro_group)

# %%
#pro_group[pro_group.columns[0:]] = pro_group[pro_group.columns[0:]].apply(pd.to_numeric, errors = 'coerce')

#pro_group.plot.bar(y=["EngSA", "EngSO"], use_index=True, rot=0, colormap='Paired')

# %%
# def plot_given_df_p(dataframe,lang1x,lang1y,lang2x,lang2y,lang3x,lang3y):
#     # Separate values to make it easier to plot
#     sep_values = pd.concat((pd.DataFrame(dataframe[col].tolist()) for col in dataframe), axis=1)
#     #Now that the columns are created they need to be renamed
#     sep_values.columns = [lang1x, lang1y, lang2x, lang2y, lang3x, lang3y]
#     #convert to numeric for plotting
#     sep_values[sep_values.columns[0:]] = sep_values[sep_values.columns[0:]].apply(pd.to_numeric, errors = 'coerce')
#     #Print out plot of data
#     c1=['#EA2027','#ED4C67']
#     ax1 = sep_values.plot(y=[lang1x,lang1y],use_index=True, rot=0,color=c1,figsize=(10, 6), title='English Probability A')
#     ax1.set_xlabel("Layers")
#     ax1.set_ylabel("Classifier Accuracy")
#     c2= ['#1e3799','#4a69bd']
#     ax2 = sep_values.plot(y=[lang2x,lang2y],use_index=True, rot=0, color=c2,figsize=(10, 6), title='German Probability A')
#     ax2.set_xlabel("Layers")
#     ax2.set_ylabel("Accuracy")
#     c3=['#079992','#38ada9']
#     ax3 = sep_values.plot(y=[lang3x,lang3y],use_index=True, rot=0, color=c3,figsize=(10, 6), title='French Probability A')
#     ax3.set_xlabel("Layers")
#     ax3.set_ylabel("Classifier Accuracy")
#     return ax1,ax2,ax3 

# def plot_given_df_np(dataframe,lang1x,lang1y,lang2x,lang2y,lang3x,lang3y):
#     # Separate values to make it easier to plot
#     sep_values = pd.concat((pd.DataFrame(dataframe[col].tolist()) for col in dataframe), axis=1)
#     #Now that the columns are created they need to be renamed
#     sep_values.columns = [lang1x, lang1y, lang2x, lang2y, lang3x, lang3y]
#     #convert to numeric for plotting
#     sep_values[sep_values.columns[0:]] = sep_values[sep_values.columns[0:]].apply(pd.to_numeric, errors = 'coerce')
#     #Print out plot of data
#     c4=['#e58e26','#f6b93b']
#     ax1 = sep_values.plot(y=[lang1x,lang1y],use_index=True, rot=0,color=c4,figsize=(10, 6), title='Korean Probability A')
#     ax1.set_xlabel("Layers")
#     ax1.set_ylabel("Classifier Accuracy")
#     c5=['#57606f','#a4b0be']
#     ax2 = sep_values.plot(y=[lang2x,lang2y],use_index=True, rot=0, color=c5,figsize=(10, 6), title='Portuguese Probability A')
#     ax2.set_xlabel("Layers")
#     ax2.set_ylabel("Accuracy")
#     c6= ['#2ed573','#009432']
#     ax3 = sep_values.plot(y=[lang3x,lang3y],use_index=True, rot=0, color=c6,figsize=(10, 6), title='Hebrew Probability A')
#     ax3.set_xlabel("Layers")
#     ax3.set_ylabel("Classifier Accuracy")
#     return ax1,ax2,ax3 


# plot_given_df_p(pro_group,"EngSA", "EngSO", "GerSA","GerSO","FreSA","FreSO")
# plot_given_df_np(non_pro_group,"KorSA","KorSO","PorSA","PorSO","HebSA","HebSO")

# %%
# col_names = ["EngSA", "EngSO", "GerSA",	"GerSO","FreSA","FreSO","KorSA","KorSO","PorSA","PorSO","HebSA","HebSO"]
# df1 = pd.read_csv('trained_on_german.csv', names=col_names, encoding="ISO-8859-1")
# df1.drop(index=[0], inplace=True)
# #print('German')
# pro_group1 = df1.iloc[:,:6]
# non_pro_group1 = df1.iloc[:,6:]
# #plot_given_df_p(pro_group1,"EngSA", "EngSO", "GerSA","GerSO","FreSA","FreSO")
# #plot_given_df_np(non_pro_group1,"KorSA","KorSO","PorSA","PorSO","HebSA","HebSO")



# col_names = ["EngSA", "EngSO", "GerSA",	"GerSO","FreSA","FreSO","KorSA","KorSO","PorSA","PorSO","HebSA","HebSO"]
# df2 = pd.read_csv('trained_on_french.csv', names=col_names, encoding="ISO-8859-1")
# df2.drop(index=[0], inplace=True)
# #print('French')
# pro_group2 = df2.iloc[:,:6]
# non_pro_group2 = df2.iloc[:,6:]
# #plot_given_df_p(pro_group2,"EngSA", "EngSO", "GerSA",	"GerSO","FreSA","FreSO")
# #plot_given_df_np(non_pro_group2,"KorSA","KorSO","PorSA","PorSO","HebSA","HebSO")


# col_names = ["EngSA", "EngSO", "GerSA",	"GerSO","FreSA","FreSO","KorSA","KorSO","PorSA","PorSO","HebSA","HebSO"]
# df3 = pd.read_csv('trained_on_korean.csv', names=col_names, encoding="ISO-8859-1")
# df3.drop(index=[0], inplace=True)
# #print('Korean')
# pro_group3 = df3.iloc[:,:6]
# non_pro_group3 = df3.iloc[:,6:]
# #plot_given_df_p(pro_group3,"EngSA", "EngSO", "GerSA",	"GerSO","FreSA","FreSO")
# #plot_given_df_np(non_pro_group3,"KorSA","KorSO","PorSA","PorSO","HebSA","HebSO")


# col_names = ["EngSA", "EngSO", "GerSA",	"GerSO","FreSA","FreSO","KorSA","KorSO","PorSA","PorSO","HebSA","HebSO"]
# df4 = pd.read_csv('trained_on_port.csv', names=col_names, encoding="ISO-8859-1")
# df4.drop(index=[0], inplace=True)
# #print('Portuguese')
# pro_group4 = df4.iloc[:,:6]
# non_pro_group4 = df4.iloc[:,6:]
# #plot_given_df_p(pro_group4,"EngSA", "EngSO", "GerSA",	"GerSO","FreSA","FreSO")
# #plot_given_df_np(non_pro_group4,"KorSA","KorSO","PorSA","PorSO","HebSA","HebSO")


# col_names = ["EngSA", "EngSO", "GerSA",	"GerSO","FreSA","FreSO","KorSA","KorSO","PorSA","PorSO","HebSA","HebSO"]
# df5 = pd.read_csv('trained_on_heb.csv', names=col_names, encoding="ISO-8859-1")
# df5.drop(index=[0], inplace=True)
# #print('Hebrew')
# pro_group5 = df5.iloc[:,:6]
# non_pro_group5 = df5.iloc[:,6:]
# #plot_given_df_p(pro_group5,"EngSA", "EngSO", "GerSA",	"GerSO","FreSA","FreSO")
# #plot_given_df_np(non_pro_group5,"KorSA","KorSO","PorSA","PorSO","HebSA","HebSO")

# %%
## Aggregating SO and SA into one for each language pair

#Flip the CSV

col_names = ["Arm","Far","Tur","Ind","Hin","Urd"]
df = pd.read_csv('agg_arm.csv', names=col_names, encoding="ISO-8859-1")
df.drop(index=[0], inplace=True)
df = df.iloc[::-1]
df = df.reset_index(drop=True)
display(df)
# Out:
#            Arm         Far         Tur         Ind         Hin         Urd
# 0    0.5913064   0.7476046  0.88644475  0.79605037   0.5730912   0.6304482
# 1    0.5562024   0.7172847  0.79048735    0.758088   0.5009986  0.66133326
# 2   0.59892374   0.6932502   0.5769795   0.7286753   0.6036312   0.6201492
# 3    0.6602172   0.7010465   0.6864558  0.73396206  0.64973277  0.67209756
# 4    0.6415028   0.6015026   0.5964983    0.675148   0.5714555   0.5773576
# 5    0.6611663   0.5875923  0.64393395  0.75461036  0.53684205   0.5679237
# 6   0.69671345   0.6551437   0.6684058  0.85265666   0.5589696   0.6244582
# 7    0.7290133  0.71339196   0.7553825   0.8954379   0.5965037   0.6507038
# 8    0.7150824   0.7421703  0.80434877   0.9083396  0.64575064    0.677925
# 9    0.7289543  0.75363463   0.8259571   0.9373258   0.6789587  0.69044566
# 10  0.73606175  0.84155095  0.85431445  0.93537986   0.7735499   0.7859384
# ...

# %%
def plot_given_df_agg(dataframe,lang1,lang2,lang3,lang4,lang5,lang6):
    # Separate values to make it easier to plot
    sep_values = pd.concat((pd.DataFrame(dataframe[col].tolist()) for col in dataframe), axis=1)
    #Now that the columns are created they need to be renamed
    sep_values.columns = [lang1,lang2,lang3,lang4,lang5,lang6]
    #convert to numeric for plotting
    sep_values[sep_values.columns[0:]] = sep_values[sep_values.columns[0:]].apply(pd.to_numeric, errors = 'coerce')
    #Print out plot of data
    c_list=['#EA2027', '#1e3799', '#079992', '#e58e26','#57606f', '#2ed573']
    ax1 = sep_values.plot(y=[lang1,lang2,lang3,lang4,lang5,lang6],use_index=True, rot=0,color=c_list,figsize=(10, 6), title='Probability A Averages on Armenian Classifier')
    ax1.set_xlabel("Layers")
    ax1.set_ylabel("Probability of A given S Averages")
    return ax1

plot_given_df_agg(df,"Arm","Far","Tur","Ind","Hin","Urd")
# Out:
# <Axes: title={'center': 'Probability A Averages on Armenian Classifier'}, xlabel='Layers', ylabel='Probability of A given S Averages'>

# %%
col_names = ["Arm","Far","Tur","Ind","Hin","Urd"]
df = pd.read_csv('agg_far.csv', names=col_names, encoding="ISO-8859-1")
df.drop(index=[0], inplace=True)
df = df.iloc[::-1]
df = df.reset_index(drop=True)
#display(df)

def plot_given_df_agg(dataframe,lang1,lang2,lang3,lang4,lang5,lang6):
    # Separate values to make it easier to plot
    sep_values = pd.concat((pd.DataFrame(dataframe[col].tolist()) for col in dataframe), axis=1)
    #Now that the columns are created they need to be renamed
    sep_values.columns = [lang1,lang2,lang3,lang4,lang5,lang6]
    #convert to numeric for plotting
    sep_values[sep_values.columns[0:]] = sep_values[sep_values.columns[0:]].apply(pd.to_numeric, errors = 'coerce')
    #Print out plot of data
    c_list=['#EA2027', '#1e3799', '#079992', '#e58e26','#57606f', '#2ed573']
    ax1 = sep_values.plot(y=[lang1,lang2,lang3,lang4,lang5,lang6],use_index=True, rot=0,color=c_list,figsize=(10, 6), title='Probability A Averages on Farsi Classifier')
    ax1.set_xlabel("Layers")
    ax1.set_ylabel("Probability of A given S Averages")
    return ax1

plot_given_df_agg(df,"Arm","Far","Tur","Ind","Hin","Urd")
# Out:
# <Axes: title={'center': 'Probability A Averages on Farsi Classifier'}, xlabel='Layers', ylabel='Probability of A given S Averages'>

# %%
col_names = ["Arm","Far","Tur","Ind","Hin","Urd"]
df = pd.read_csv('agg_tur.csv', names=col_names, encoding="ISO-8859-1")
df.drop(index=[0], inplace=True)
df = df.iloc[::-1]
df = df.reset_index(drop=True)
#display(df)

def plot_given_df_agg(dataframe,lang1,lang2,lang3,lang4,lang5,lang6):
    # Separate values to make it easier to plot
    sep_values = pd.concat((pd.DataFrame(dataframe[col].tolist()) for col in dataframe), axis=1)
    #Now that the columns are created they need to be renamed
    sep_values.columns = [lang1,lang2,lang3,lang4,lang5,lang6]
    #convert to numeric for plotting
    sep_values[sep_values.columns[0:]] = sep_values[sep_values.columns[0:]].apply(pd.to_numeric, errors = 'coerce')
    #Print out plot of data
    c_list=['#EA2027', '#1e3799', '#079992', '#e58e26','#57606f', '#2ed573']
    ax1 = sep_values.plot(y=[lang1,lang2,lang3,lang4,lang5,lang6],use_index=True, rot=0,color=c_list,figsize=(10, 6), title='Probability A Averages on Turkish Classifier')
    ax1.set_xlabel("Layers")
    ax1.set_ylabel("Probability of A given S Averages")
    return ax1

plot_given_df_agg(df,"Arm","Far","Tur","Ind","Hin","Urd")
# Out:
# <Axes: title={'center': 'Probability A Averages on Turkish Classifier'}, xlabel='Layers', ylabel='Probability of A given S Averages'>

# %%
col_names = ["Arm","Far","Tur","Ind","Hin","Urd"]
df = pd.read_csv('agg_ind.csv', names=col_names, encoding="ISO-8859-1")
df.drop(index=[0], inplace=True)
df = df.iloc[::-1]
df = df.reset_index(drop=True)
#display(df)

def plot_given_df_agg(dataframe,lang1,lang2,lang3,lang4,lang5,lang6):
    # Separate values to make it easier to plot
    sep_values = pd.concat((pd.DataFrame(dataframe[col].tolist()) for col in dataframe), axis=1)
    #Now that the columns are created they need to be renamed
    sep_values.columns = [lang1,lang2,lang3,lang4,lang5,lang6]
    #convert to numeric for plotting
    sep_values[sep_values.columns[0:]] = sep_values[sep_values.columns[0:]].apply(pd.to_numeric, errors = 'coerce')
    #Print out plot of data
    c_list=['#EA2027', '#1e3799', '#079992', '#e58e26','#57606f', '#2ed573']
    ax1 = sep_values.plot(y=[lang1,lang2,lang3,lang4,lang5,lang6],use_index=True, rot=0,color=c_list,figsize=(10, 6), title='Probability A Averages on Indonesian Classifier')
    ax1.set_xlabel("Layers")
    ax1.set_ylabel("Probability of A given S Averages")
    return ax1

plot_given_df_agg(df,"Arm","Far","Tur","Ind","Hin","Urd")
# Out:
# <Axes: title={'center': 'Probability A Averages on Indonesian Classifier'}, xlabel='Layers', ylabel='Probability of A given S Averages'>

# %%
col_names = ["Arm","Far","Tur","Ind","Hin","Urd"]
df = pd.read_csv('agg_hin.csv', names=col_names, encoding="ISO-8859-1")
df.drop(index=[0], inplace=True)
df = df.iloc[::-1]
df = df.reset_index(drop=True)
#display(df)

def plot_given_df_agg(dataframe,lang1,lang2,lang3,lang4,lang5,lang6):
    # Separate values to make it easier to plot
    sep_values = pd.concat((pd.DataFrame(dataframe[col].tolist()) for col in dataframe), axis=1)
    #Now that the columns are created they need to be renamed
    sep_values.columns = [lang1,lang2,lang3,lang4,lang5,lang6]
    #convert to numeric for plotting
    sep_values[sep_values.columns[0:]] = sep_values[sep_values.columns[0:]].apply(pd.to_numeric, errors = 'coerce')
    #Print out plot of data
    c_list=['#EA2027', '#1e3799', '#079992', '#e58e26','#57606f', '#2ed573']
    ax1 = sep_values.plot(y=[lang1,lang2,lang3,lang4,lang5,lang6],use_index=True, rot=0,color=c_list,figsize=(10, 6), title='Probability A Averages on Hindi Classifier')
    ax1.set_xlabel("Layers")
    ax1.set_ylabel("Probability of A given S Averages")
    return ax1

plot_given_df_agg(df,"Arm","Far","Tur","Ind","Hin","Urd")
# Out:
# <Axes: title={'center': 'Probability A Averages on Hindi Classifier'}, xlabel='Layers', ylabel='Probability of A given S Averages'>

# %%
col_names = ["Arm","Far","Tur","Ind","Hin","Urd"]
df = pd.read_csv('agg_urd.csv', names=col_names, encoding="ISO-8859-1")
df.drop(index=[0], inplace=True)
df = df.iloc[::-1]
df = df.reset_index(drop=True)
#display(df)

def plot_given_df_agg(dataframe,lang1,lang2,lang3,lang4,lang5,lang6):
    # Separate values to make it easier to plot
    sep_values = pd.concat((pd.DataFrame(dataframe[col].tolist()) for col in dataframe), axis=1)
    #Now that the columns are created they need to be renamed
    sep_values.columns = [lang1,lang2,lang3,lang4,lang5,lang6]
    #convert to numeric for plotting
    sep_values[sep_values.columns[0:]] = sep_values[sep_values.columns[0:]].apply(pd.to_numeric, errors = 'coerce')
    #Print out plot of data
    c_list=['#EA2027', '#1e3799', '#079992', '#e58e26','#57606f', '#2ed573']
    ax1 = sep_values.plot(y=[lang1,lang2,lang3,lang4,lang5,lang6],use_index=True, rot=0,color=c_list,figsize=(10, 6), title='Probability A Averages on Urdu Classifier')
    ax1.set_xlabel("Layers")
    ax1.set_ylabel("Probability of A given S Averages")
    return ax1

plot_given_df_agg(df,"Arm","Far","Tur","Ind","Hin","Urd")
# Out:
# <Axes: title={'center': 'Probability A Averages on Urdu Classifier'}, xlabel='Layers', ylabel='Probability of A given S Averages'>

# %%
# col_names = ["Bul","Cze","Slo","Cat","Ita","Rom"]
# df1 = pd.read_csv('agg_cze.csv', names=col_names, encoding="ISO-8859-1")
# df1.drop(index=[0], inplace=True)
# df1 = df1.iloc[::-1]
# plot_given_df_agg(df1,"Bul","Cze","Slo","Cat","Ita","Rom")

# col_names = ["Bul","Cze","Slo","Cat","Ita","Rom"]
# df2 = pd.read_csv('agg_slo.csv', names=col_names, encoding="ISO-8859-1")
# df2.drop(index=[0], inplace=True)
# df2 = df2.iloc[::-1]
# plot_given_df_agg(df2,"Bul","Cze","Slo","Cat","Ita","Rom")

# col_names = ["Bul","Cze","Slo","Cat","Ita","Rom"]
# df3 = pd.read_csv('agg_cat.csv', names=col_names, encoding="ISO-8859-1")
# df3.drop(index=[0], inplace=True)
# df3 = df3.iloc[::-1]
# plot_given_df_agg(df3,"Bul","Cze","Slo","Cat","Ita","Rom")

# col_names = ["Bul","Cze","Slo","Cat","Ita","Rom"]
# df4 = pd.read_csv('agg_ita.csv', names=col_names, encoding="ISO-8859-1")
# df4.drop(index=[0], inplace=True)
# df4 = df4.iloc[::-1]
# plot_given_df_agg(df4,"Bul","Cze","Slo","Cat","Ita","Rom")

col_names = ["Bul","Cze","Slo","Cat","Ita","Rom"]
df5 = pd.read_csv('agg_rom.csv', names=col_names, encoding="ISO-8859-1")
df5.drop(index=[0], inplace=True)
df5 = df5.iloc[::-1]
plot_given_df_agg(df5,"Bul","Cze","Slo","Cat","Ita","Rom")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 26
#       1 # col_names = ["Bul","Cze","Slo","Cat","Ita","Rom"]
#       2 # df1 = pd.read_csv('agg_cze.csv', names=col_names, encoding="ISO-8859-1")
#       3 # df1.drop(index=[0], inplace=True)
#    (...)
#      22 # df4 = df4.iloc[::-1]
#      23 # plot_given_df_agg(df4,"Bul","Cze","Slo","Cat","Ita","Rom")
#      25 col_names = ["Bul","Cze","Slo","Cat","Ita","Rom"]
# ---> 26 df5 = pd.read_csv('agg_rom.csv', names=col_names, encoding="ISO-8859-1")
#      27 df5.drop(index=[0], inplace=True)
#      28 df5 = df5.iloc[::-1]
#
# File ~/miniforge3/envs/erg_nom/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...
