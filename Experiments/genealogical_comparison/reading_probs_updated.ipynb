# %%
import pandas as pd

# %%
with open("romanian_classifier_copy", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df = pd.DataFrame([sub.split(",") for sub in read_file])
display(df)
#df.to_csv("romanian_data.csv", sep=',')
# Out:
# <class 'list'>
#           0          1     2        3               4          5   \
# 0                  role  case  animacy    subject_word  verb_word
# 1          0          O                                     arăta
# 2          1          S                      băiețelul       țipa
# 3          2          O                                      vârî
# 4          3          A                         femeia    strânge
# ...      ...        ...   ...      ...             ...        ...
# 14972  14971  S-passive                        incintă     folosi
# 14973  14972  S-passive                      electrozi       găsi
# 14974  14973  S-passive                      diferență     aplica
# 14975  14974  S-passive                 caracteristica      trasa
# 14976  14975  S-passive                           legi     obține
#
#                 6               7                       8      9   \
# 0      object_word  predicted_role           probability_A  layer
# 1            barcă               O   3.098553179370356e-06     12
# 2                                A      0.9999991655349731     12
# 3            capul               O  1.3014669093536213e-06     12
# 4               îl               A      0.9972330927848816     12
# ...            ...             ...                     ...    ...
# 14972                            O     0.20644570887088776      0
# 14973                            O     0.00902768224477768      0
# 14974                            O      0.1716090440750122      0
# 14975                            O     0.16653881967067719      0
# 14976                            A      0.6348556280136108      0
#
#                            10                        11    12
# 0      source_test_accuracy_A  source_test_accuracy_O\n  None
# 1          0.9069767441860465      0.7852998065764023\n  None
# 2          0.9069767441860465      0.7852998065764023\n  None
# 3          0.9069767441860465      0.7852998065764023\n  None
# 4          0.9069767441860465      0.7852998065764023\n  None
# ...                       ...                       ...   ...
# 14972      0.6744186046511628      0.7311411992263056\n  None
# 14973      0.6744186046511628      0.7311411992263056\n  None
# 14974      0.6744186046511628      0.7311411992263056\n  None
# 14975      0.6744186046511628      0.7311411992263056\n  None
# 14976      0.6744186046511628      0.7311411992263056\n  None
#
# [14977 rows x 13 columns]

# %%
filtered_df = df[[1,7,8,9,10,11]]
display(filtered_df.head(20))
# Out:
#            1               7                       8      9   \
# 0        role  predicted_role           probability_A  layer
# 1           O               O   3.098553179370356e-06     12
# 2           S               A      0.9999991655349731     12
# 3           O               O  1.3014669093536213e-06     12
# 4           A               A      0.9972330927848816     12
# 5           S               O   0.0052201454527676105     12
# 6           A               A      0.9999723434448242     12
# 7           O               O  0.00020416751794982702     12
# 8           S               O   7.566432759631425e-05     12
# 9           S               A      0.9990077614784241     12
# 10          A               O   0.0006565615185536444     12
# 11          O               O     0.02305525727570057     12
# 12          A               O   0.0027180674951523542     12
# 13          O               O     4.8333063773498e-08     12
# 14          S               O     0.11147458106279373     12
# 15          A               A      0.9372696280479431     12
# 16          O               O   9.598711039870977e-05     12
# 17          S               O     0.09329712390899658     12
# 18  S-passive               O   0.0016886875964701176     12
# 19          S               O   0.0005238223820924759     12
#
#                         10                        11
# 0   source_test_accuracy_A  source_test_accuracy_O\n
# 1       0.9069767441860465      0.7852998065764023\n
# 2       0.9069767441860465      0.7852998065764023\n
# 3       0.9069767441860465      0.7852998065764023\n
# 4       0.9069767441860465      0.7852998065764023\n
# 5       0.9069767441860465      0.7852998065764023\n
# 6       0.9069767441860465      0.7852998065764023\n
# 7       0.9069767441860465      0.7852998065764023\n
# 8       0.9069767441860465      0.7852998065764023\n
# 9       0.9069767441860465      0.7852998065764023\n
# 10      0.9069767441860465      0.7852998065764023\n
# 11      0.9069767441860465      0.7852998065764023\n
# 12      0.9069767441860465      0.7852998065764023\n
# 13      0.9069767441860465      0.7852998065764023\n
# 14      0.9069767441860465      0.7852998065764023\n
# 15      0.9069767441860465      0.7852998065764023\n
# 16      0.9069767441860465      0.7852998065764023\n
# 17      0.9069767441860465      0.7852998065764023\n
# 18      0.9069767441860465      0.7852998065764023\n
# 19      0.9069767441860465      0.7852998065764023\n

# %%
only_S = filtered_df.loc[filtered_df[1] == 'S']
display(only_S)
# Out:
#       1  7                      8   9                   10  \
# 2      S  A     0.9999991655349731  12  0.9069767441860465
# 5      S  O  0.0052201454527676105  12  0.9069767441860465
# 8      S  O  7.566432759631425e-05  12  0.9069767441860465
# 9      S  A     0.9990077614784241  12  0.9069767441860465
# 14     S  O    0.11147458106279373  12  0.9069767441860465
# ...   .. ..                    ...  ..                 ...
# 14966  S  O     0.2438696175813675   0  0.6744186046511628
# 14967  S  O    0.24439439177513123   0  0.6744186046511628
# 14968  S  A                    1.0   0  0.6744186046511628
# 14970  S  A     0.9999293088912964   0  0.6744186046511628
# 14971  S  A     0.9999998807907104   0  0.6744186046511628
#
#                          11
# 2      0.7852998065764023\n
# 5      0.7852998065764023\n
# 8      0.7852998065764023\n
# 9      0.7852998065764023\n
# 14     0.7852998065764023\n
# ...                     ...
# 14966  0.7311411992263056\n
# 14967  0.7311411992263056\n
# 14968  0.7311411992263056\n
# 14970  0.7311411992263056\n
# 14971  0.7311411992263056\n
#
# [3978 rows x 6 columns]

# %%
obj_col = only_S.loc[only_S[7] == 'O']
display(obj_col)
# Out:
#       1  7                       8   9                   10  \
# 14     S  O     0.11147458106279373  12  0.9069767441860465
# 19     S  O    0.017848946154117584  12  0.9069767441860465
# 22     S  O    0.021560681983828545  12  0.9069767441860465
# 48     S  O    0.002665736945345998  12  0.9069767441860465
# 49     S  O     0.18798597157001495  12  0.9069767441860465
# ...   .. ..                     ...  ..                 ...
# 14879  S  O      0.0345090813934803   0  0.6744186046511628
# 14917  S  O  0.00019092310685664415   0  0.6744186046511628
# 14950  S  O       0.398413747549057   0  0.6744186046511628
# 14966  S  O      0.2438696175813675   0  0.6744186046511628
# 14967  S  O     0.24439439177513123   0  0.6744186046511628
#
#                          11
# 14     0.7852998065764023\n
# 19     0.7852998065764023\n
# 22     0.7852998065764023\n
# 48     0.7852998065764023\n
# 49     0.7852998065764023\n
# ...                     ...
# 14879  0.7311411992263056\n
# 14917  0.7311411992263056\n
# 14950  0.7311411992263056\n
# 14966  0.7311411992263056\n
# 14967  0.7311411992263056\n
#
# [409 rows x 6 columns]

# %%
agent_col = only_S.loc[only_S[7] == 'A']
display(agent_col)
# Out:
#       1  7                   8   9                   10                    11
# 9      S  A  0.9990077614784241  12  0.9069767441860465  0.7852998065764023\n
# 56     S  A                 0.5  12  0.9069767441860465  0.7852998065764023\n
# 136    S  A  0.9442647099494934  12  0.9069767441860465  0.7852998065764023\n
# 163    S  A  0.9974725842475891  12  0.9069767441860465  0.7852998065764023\n
# 201    S  A  0.8354941010475159  12  0.9069767441860465  0.7852998065764023\n
# ...   .. ..                 ...  ..                 ...                   ...
# 14923  S  A                 1.0   0  0.6744186046511628  0.7311411992263056\n
# 14928  S  A  0.9999868869781494   0  0.6744186046511628  0.7311411992263056\n
# 14930  S  A  0.9999969005584717   0  0.6744186046511628  0.7311411992263056\n
# 14943  S  A  0.5279226899147034   0  0.6744186046511628  0.7311411992263056\n
# 14970  S  A  0.9916623830795288   0  0.6744186046511628  0.7311411992263056\n
#
# [917 rows x 6 columns]

# %%
### Returns the SA and SO averages of Probability A column for each layer

layer12 = only_S[only_S[9]== '12']
#display(layer12)
layer12[8] = pd.to_numeric(layer12[8], downcast="float")
print(layer12[8].mean())

layer11 = only_S[only_S[9]== '11']
#display(layer11)
layer11[8] = pd.to_numeric(layer11[8], downcast="float")
print(layer11[8].mean())

layer10 = only_S[only_S[9]== '10']
#display(layer10)
layer10[8] = pd.to_numeric(layer10[8], downcast="float")
print(layer10[8].mean())

layer9 = only_S[only_S[9]== '9']
#display(layer9)
layer9[8] = pd.to_numeric(layer9[8], downcast="float")
print(layer9[8].mean())

layer8 = only_S[only_S[9]== '8']
#display(layer8)
layer8[8] = pd.to_numeric(layer8[8], downcast="float")
print(layer8[8].mean())

layer7 = only_S[only_S[9]== '7']
#display(layer7)
layer7[8] = pd.to_numeric(layer7[8], downcast="float")
print(layer7[8].mean())

layer6 = only_S[only_S[9]== '6']
#display(layer6)
layer6[8] = pd.to_numeric(layer6[8], downcast="float")
print(layer6[8].mean())

layer5 = only_S[only_S[9]== '5']
#display(layer10)
layer5[8] = pd.to_numeric(layer5[8], downcast="float")
print(layer5[8].mean())

layer4 = only_S[only_S[9]== '4']
#display(layer9)
layer4[8] = pd.to_numeric(layer4[8], downcast="float")
print(layer4[8].mean())

layer3 = only_S[only_S[9]== '3']
#display(layer8)
layer3[8] = pd.to_numeric(layer3[8], downcast="float")
print(layer3[8].mean())

layer2 = only_S[only_S[9]== '2']
#display(layer7)
layer2[8] = pd.to_numeric(layer2[8], downcast="float")
print(layer2[8].mean())

layer1 = only_S[only_S[9]== '1']
#display(layer6)
layer1[8] = pd.to_numeric(layer1[8], downcast="float")
print(layer1[8].mean())

layer0 = only_S[only_S[9]== '0']
#display(layer6)
layer0[8] = pd.to_numeric(layer0[8], downcast="float")
print(layer0[8].mean())
# Out:
# 0.7771418
# 0.784146
# 0.80241567
# 0.8003935
# 0.81377244
# 0.808412
# 0.7864685
# 0.7709971
# 0.7667171
# 0.743635
# 0.63826656
# 0.57318795
# 0.6358259
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/1109710783.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer12[8] = pd.to_numeric(layer12[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/1109710783.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer11[8] = pd.to_numeric(layer11[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/1109710783.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer10[8] = pd.to_numeric(layer10[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/1109710783.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer9[8] = pd.to_numeric(layer9[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/1109710783.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer8[8] = pd.to_numeric(layer8[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/1109710783.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer7[8] = pd.to_numeric(layer7[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/1109710783.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer6[8] = pd.to_numeric(layer6[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/1109710783.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer5[8] = pd.to_numeric(layer5[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/1109710783.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer4[8] = pd.to_numeric(layer4[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/1109710783.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer3[8] = pd.to_numeric(layer3[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/1109710783.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer2[8] = pd.to_numeric(layer2[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/1109710783.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer1[8] = pd.to_numeric(layer1[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/1109710783.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer0[8] = pd.to_numeric(layer0[8], downcast="float")

# %%
### Returns the SA averages of Probability A column for each layer

layer12_agent = agent_col[agent_col[9]== '12']
#display(layer12_agent)
layer12_agent[8] = pd.to_numeric(layer12_agent[8], downcast="float")
print(layer12_agent[8].mean())

layer11_agent = agent_col[agent_col[9]== '11']
#display(layer11_agent)
layer11_agent[8] = pd.to_numeric(layer11_agent[8], downcast="float")
print(layer11_agent[8].mean())

layer10_agent = agent_col[agent_col[9]== '10']
#display(layer10_agent)
layer10_agent[8] = pd.to_numeric(layer10_agent[8], downcast="float")
print(layer10_agent[8].mean())

layer9_agent = agent_col[agent_col[9]== '9']
#display(layer9_agent)
layer9_agent[8] = pd.to_numeric(layer9_agent[8], downcast="float")
print(layer9_agent[8].mean())

layer8_agent = agent_col[agent_col[9]== '8']
#display(layer8_agent)
layer8_agent[8] = pd.to_numeric(layer8_agent[8], downcast="float")
print(layer8_agent[8].mean())

layer7_agent = agent_col[agent_col[9]== '7']
#display(layer7_agent)
layer7_agent[8] = pd.to_numeric(layer7_agent[8], downcast="float")
print(layer7_agent[8].mean())

layer6_agent = agent_col[agent_col[9]== '6']
#display(layer6_agent)
layer6_agent[8] = pd.to_numeric(layer6_agent[8], downcast="float")
print(layer6_agent[8].mean())

layer5_agent = agent_col[agent_col[9]== '5']
#display(layer10_agent)
layer5_agent[8] = pd.to_numeric(layer5_agent[8], downcast="float")
print(layer5_agent[8].mean())

layer4_agent = agent_col[agent_col[9]== '4']
#display(layer9_agent)
layer4_agent[8] = pd.to_numeric(layer4_agent[8], downcast="float")
print(layer4_agent[8].mean())

layer3_agent = agent_col[agent_col[9]== '3']
#display(layer8_agent)
layer3_agent[8] = pd.to_numeric(layer3_agent[8], downcast="float")
print(layer3_agent[8].mean())

layer2_agent = agent_col[agent_col[9]== '2']
#display(layer7_agent)
layer2_agent[8] = pd.to_numeric(layer2_agent[8], downcast="float")
print(layer2_agent[8].mean())

layer1_agent = agent_col[agent_col[9]== '1']
#display(layer6_agent)
layer1_agent[8] = pd.to_numeric(layer1_agent[8], downcast="float")
print(layer1_agent[8].mean())

layer0_agent = agent_col[agent_col[9]== '0']
#display(layer6_agent)
layer0_agent[8] = pd.to_numeric(layer0_agent[8], downcast="float")
print(layer0_agent[8].mean())
# Out:
# 0.9273812
# 0.965665
# 0.9799949
# 0.95210946
# 0.9857063
# 0.95256436
# 0.97986656
# 0.9712798
# 0.96986794
# 0.95543224
# 0.9508681
# 0.93727
# 0.928695
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/770741630.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer12_agent[8] = pd.to_numeric(layer12_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/770741630.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer11_agent[8] = pd.to_numeric(layer11_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/770741630.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer10_agent[8] = pd.to_numeric(layer10_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/770741630.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer9_agent[8] = pd.to_numeric(layer9_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/770741630.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer8_agent[8] = pd.to_numeric(layer8_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/770741630.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer7_agent[8] = pd.to_numeric(layer7_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/770741630.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer6_agent[8] = pd.to_numeric(layer6_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/770741630.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer5_agent[8] = pd.to_numeric(layer5_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/770741630.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer4_agent[8] = pd.to_numeric(layer4_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/770741630.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer3_agent[8] = pd.to_numeric(layer3_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/770741630.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer2_agent[8] = pd.to_numeric(layer2_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/770741630.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer1_agent[8] = pd.to_numeric(layer1_agent[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/770741630.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer0_agent[8] = pd.to_numeric(layer0_agent[8], downcast="float")

# %%
### Returns the SO averages of Probability A column for each layer


layer12_obj = obj_col[obj_col[9]== '12']
#display(layer12_obj)
layer12_obj[8] = pd.to_numeric(layer12_obj[8], downcast="float")
print(layer12_obj[8].mean())

layer11_obj = obj_col[obj_col[9]== '11']
#display(layer11_obj)
layer11_obj[8] = pd.to_numeric(layer11_obj[8], downcast="float")
print(layer11_obj[8].mean())

layer10_obj = obj_col[obj_col[9]== '10']
#display(layer10_agent)
layer10_obj[8] = pd.to_numeric(layer10_obj[8], downcast="float")
print(layer10_obj[8].mean())

layer9_obj = obj_col[obj_col[9]== '9']
#display(layer9_agent)
layer9_obj[8] = pd.to_numeric(layer9_obj[8], downcast="float")
print(layer9_obj[8].mean())

layer8_obj = obj_col[obj_col[9]== '8']
#display(layer8_agent)
layer8_obj[8] = pd.to_numeric(layer8_obj[8], downcast="float")
print(layer8_obj[8].mean())

layer7_obj = obj_col[obj_col[9]== '7']
#display(layer7_agent)
layer7_obj[8] = pd.to_numeric(layer7_obj[8], downcast="float")
print(layer7_obj[8].mean())

layer6_obj = obj_col[obj_col[9]== '6']
#display(layer6_agent)
layer6_obj[8] = pd.to_numeric(layer6_obj[8], downcast="float")
print(layer6_obj[8].mean())

layer5_obj = obj_col[obj_col[9]== '5']
#display(layer10_agent)
layer5_obj[8] = pd.to_numeric(layer5_obj[8], downcast="float")
print(layer5_obj[8].mean())

layer4_obj = obj_col[obj_col[9]== '4']
#display(layer9_agent)
layer4_obj[8] = pd.to_numeric(layer4_obj[8], downcast="float")
print(layer4_obj[8].mean())

layer3_obj = obj_col[obj_col[9]== '3']
#display(layer8_agent)
layer3_obj[8] = pd.to_numeric(layer3_obj[8], downcast="float")
print(layer3_obj[8].mean())

layer2_obj = obj_col[obj_col[9]== '2']
#display(layer7_agent)
layer2_obj[8] = pd.to_numeric(layer2_obj[8], downcast="float")
print(layer2_obj[8].mean())

layer1_obj = obj_col[obj_col[9]== '1']
#display(layer6_agent)
layer1_obj[8] = pd.to_numeric(layer1_obj[8], downcast="float")
print(layer1_obj[8].mean())

layer0_obj = obj_col[obj_col[9]== '0']
#display(layer6_agent)
layer0_obj[8] = pd.to_numeric(layer0_obj[8], downcast="float")
print(layer0_obj[8].mean())
# Out:
# 0.051732942
# 0.063615344
# 0.058543183
# 0.099253275
# 0.062243618
# 0.016162844
# 0.03565226
# 0.050511558
# 0.074945174
# 0.058704674
# 0.059232306
# 0.09337885
# 0.10948189
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/730305013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer12_obj[8] = pd.to_numeric(layer12_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/730305013.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer11_obj[8] = pd.to_numeric(layer11_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/730305013.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer10_obj[8] = pd.to_numeric(layer10_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/730305013.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer9_obj[8] = pd.to_numeric(layer9_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/730305013.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer8_obj[8] = pd.to_numeric(layer8_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/730305013.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer7_obj[8] = pd.to_numeric(layer7_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/730305013.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer6_obj[8] = pd.to_numeric(layer6_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/730305013.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer5_obj[8] = pd.to_numeric(layer5_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/730305013.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer4_obj[8] = pd.to_numeric(layer4_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/730305013.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer3_obj[8] = pd.to_numeric(layer3_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/730305013.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer2_obj[8] = pd.to_numeric(layer2_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/730305013.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer1_obj[8] = pd.to_numeric(layer1_obj[8], downcast="float")
# /var/folders/49/431zj7ys6_n42jcfj9z6ycb80000gn/T/ipykernel_18285/730305013.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   layer0_obj[8] = pd.to_numeric(layer0_obj[8], downcast="float")
