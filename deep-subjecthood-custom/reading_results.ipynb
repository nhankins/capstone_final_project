# %%
import pandas as pd

## Opens .conllu output for language classifier comparisons 
## Hindi basq

with open("results/latest_run/hi_hdtb-ud_eu_bdt-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df1 = pd.DataFrame([sub.split(",") for sub in read_file])
df1.head(5)

# new_header1 = df1.iloc[0] 
# df1 = df1[1:] 
# df1.columns = new_header1 
# df1["probability_A"] = pd.to_numeric(df1["probability_A"], errors='coerce')
# df1["probability_A"].mean()

df_roles = df1[[1,7]]
roles_header = df_roles.iloc[0]
df_roles = df_roles[1:]
df_roles.columns = roles_header
df_roles

df1_predict_acc = df_roles.apply(lambda row: all(i in row.predicted_role for i in row.role), axis=1)
#df1_predict_acc.value_counts()
#Prediction matches over all layers True = 13243 (0.50934), False = 12757 (0.4906)

#df1.to_csv('df1.csv', index=False)
# Out:
# <class 'list'>

# %%
## Hindi Indo

with open("results/latest_run/hi_hdtb-ud_id_gsd-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df2 = pd.DataFrame([sub.split(",") for sub in read_file])
df2.head(15)
# Out:
# <class 'list'>
#     0          1     2        3             4          5            6   \
# 0            role  case  animacy  subject_word  verb_word  object_word
# 1    0          S                     serangan    terjadi
# 2    1          O                                   bakar        rumah
# 3    2          O                               memenggal     penghuni
# 4    3  S-passive                 Perkembangan       ikut
# 5    4          A                        kapal     tembak        salvo
# 6    5          O                                  tembak        salvo
# 7    6          O                                  sarang      torpedo
# 8    7          O                                   parah    kerusakan
# 9    8  S-passive                      Pasukan     siasat
# 10   9          A                        Krogh       buat        studi
# 11  10          O                                    buat        studi
# 12  11  S-passive                         Lagu     tampil
# ...

# %%
## Hindi mara

with open("results/latest_run/hi_hdtb-ud_mr_ufal-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df3 = pd.DataFrame([sub.split(",") for sub in read_file])
df3.head(5)
# Out:
# <class 'list'>
#   0     1     2        3             4          5            6   \
# 0     role  case  animacy  subject_word  verb_word  object_word
# 1  0     A   Nom                   राजा       करित       त्याला
# 2  1     S   Nom                   राजा     म्हणणे
# 3  2     S   Nom             टक्केटोणपे       खाणे
# 4  3     A   Erg                 राजाने     सांगणे        विचार
#
#                7                    8      9                       10  \
# 0  predicted_role        probability_A  layer  source_test_accuracy_A
# 1               A                  1.0     12        0.88996138996139
# 2               A   0.9999496936798096     12        0.88996138996139
# 3               O  0.17719615995883942     12        0.88996138996139
# 4               A   0.9999946355819702     12        0.88996138996139
#
#                          11
# 0  source_test_accuracy_O\n
# 1      0.8623326959847036\n
# 2      0.8623326959847036\n
# 3      0.8623326959847036\n
# ...

# %%
## Hindi ukr

with open("results/latest_run/hi_hdtb-ud_uk_iu-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df4 = pd.DataFrame([sub.split(",") for sub in read_file])
df4.head(5)
# Out:
# <class 'list'>
#   0     1     2        3             4           5            6   \
# 0     role  case  animacy  subject_word   verb_word  object_word
# 1  0     S   Nom     Inan        фреска        бути
# 2  1     S   Nom     Anim     одновірці   зібратися
# 3  2     O   Acc     Inan                замазувати        стіну
# 4  3     O   Acc     Inan                   знищити   мальовидло
#
#                7                      8      9                       10  \
# 0  predicted_role          probability_A  layer  source_test_accuracy_A
# 1               A      0.918612003326416     12        0.88996138996139
# 2               A     0.9943737983703613     12        0.88996138996139
# 3               O  0.0009756358340382576     12        0.88996138996139
# 4               O      0.194249227643013     12        0.88996138996139
#
#                          11
# 0  source_test_accuracy_O\n
# 1      0.8623326959847036\n
# 2      0.8623326959847036\n
# 3      0.8623326959847036\n
# ...

# %%
## Hindi urdu

with open("results/latest_run/hi_hdtb-ud_ur_udtb-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df5 = pd.DataFrame([sub.split(",") for sub in read_file])
df5.head(5)
# Out:
# <class 'list'>
#   0     1     2        3             4          5            6   \
# 0     role  case  animacy  subject_word  verb_word  object_word
# 1  0     S   Nom                  اجلاس         ہو
# 2  1     S   Nom                   بورڈ         کر
# 3  2     O   Nom                                کر         اپیل
# 4  3     A   Acc                   بورڈ       کروا       اپیلیں
#
#                7                      8      9                       10  \
# 0  predicted_role          probability_A  layer  source_test_accuracy_A
# 1               O   0.003561136545613408     12        0.88996138996139
# 2               A     0.9438534379005432     12        0.88996138996139
# 3               O  0.0025441960897296667     12        0.88996138996139
# 4               A                    1.0     12        0.88996138996139
#
#                          11
# 0  source_test_accuracy_O\n
# 1      0.8623326959847036\n
# 2      0.8623326959847036\n
# 3      0.8623326959847036\n
# ...

# %%
## Hindi hindi (exp 1?)

with open("results/latest_run/hi_hdtb-ud_hi_hdtb-ud-test.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df6 = pd.DataFrame([sub.split(",") for sub in read_file])
df6.head(5)
# Out:
# <class 'list'>
#   0     1     2        3             4          5            6   \
# 0     role  case  animacy  subject_word  verb_word  object_word
# 1  0     O   Nom                               खुल           पट
# 2  1     S   Acc                पार्वती         कर
# 3  2     O   Acc                                पा       महादेव
# 4  3     S   Nom                   धूनी         जल
#
#                7                       8      9                       10  \
# 0  predicted_role           probability_A  layer  source_test_accuracy_A
# 1               O   4.512222915309394e-07     12        0.88996138996139
# 2               A      0.9999996423721313     12        0.88996138996139
# 3               O  2.9772260745630774e-07     12        0.88996138996139
# 4               O    0.003478792728856206     12        0.88996138996139
#
#                          11
# 0  source_test_accuracy_O\n
# 1      0.8623326959847036\n
# 2      0.8623326959847036\n
# 3      0.8623326959847036\n
# ...

# %%
## basque indo

with open("results/latest_run/eu_bdt-ud_id_gsd-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df7 = pd.DataFrame([sub.split(",") for sub in read_file])
df7.head(5)
# Out:
# <class 'list'>
#   0          1     2        3             4          5            6   \
# 0          role  case  animacy  subject_word  verb_word  object_word
# 1  0          S                     serangan    terjadi
# 2  1          O                                   bakar        rumah
# 3  2          O                               memenggal     penghuni
# 4  3  S-passive                 Perkembangan       ikut
#
#                7                      8      9                       10  \
# 0  predicted_role          probability_A  layer  source_test_accuracy_A
# 1               A     0.8681724667549133     12      0.8652694610778443
# 2               O  8.161691198438348e-07     12      0.8652694610778443
# 3               O    0.35661888122558594     12      0.8652694610778443
# 4               A     0.9529194235801697     12      0.8652694610778443
#
#                          11
# 0  source_test_accuracy_O\n
# 1      0.8185880250223414\n
# 2      0.8185880250223414\n
# ...

# %%
## basque mara

with open("results/latest_run/eu_bdt-ud_mr_ufal-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df8 = pd.DataFrame([sub.split(",") for sub in read_file])
df8.head(5)
# Out:
# <class 'list'>
#   0     1     2        3             4          5            6   \
# 0     role  case  animacy  subject_word  verb_word  object_word
# 1  0     A   Nom                   राजा       करित       त्याला
# 2  1     S   Nom                   राजा     म्हणणे
# 3  2     S   Nom             टक्केटोणपे       खाणे
# 4  3     A   Erg                 राजाने     सांगणे        विचार
#
#                7                   8      9                       10  \
# 0  predicted_role       probability_A  layer  source_test_accuracy_A
# 1               A  0.9872235059738159     12      0.8652694610778443
# 2               A  0.6848072409629822     12      0.8652694610778443
# 3               A  0.8198820352554321     12      0.8652694610778443
# 4               A  0.9896479249000549     12      0.8652694610778443
#
#                          11
# 0  source_test_accuracy_O\n
# 1      0.8185880250223414\n
# 2      0.8185880250223414\n
# 3      0.8185880250223414\n
# ...

# %%
## basque ukr

with open("results/latest_run/eu_bdt-ud_uk_iu-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df9 = pd.DataFrame([sub.split(",") for sub in read_file])
df9.head(5)
# Out:
# <class 'list'>
#   0     1     2        3             4           5            6   \
# 0     role  case  animacy  subject_word   verb_word  object_word
# 1  0     S   Nom     Inan        фреска        бути
# 2  1     S   Nom     Anim     одновірці   зібратися
# 3  2     O   Acc     Inan                замазувати        стіну
# 4  3     O   Acc     Inan                   знищити   мальовидло
#
#                7                      8      9                       10  \
# 0  predicted_role          probability_A  layer  source_test_accuracy_A
# 1               A     0.9561126232147217     12      0.8652694610778443
# 2               A     0.9988012313842773     12      0.8652694610778443
# 3               O  7.054072193568572e-05     12      0.8652694610778443
# 4               O   0.005626329220831394     12      0.8652694610778443
#
#                          11
# 0  source_test_accuracy_O\n
# 1      0.8185880250223414\n
# 2      0.8185880250223414\n
# 3      0.8185880250223414\n
# ...

# %%
## basque urdu

with open("results/latest_run/eu_bdt-ud_ur_udtb-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df10 = pd.DataFrame([sub.split(",") for sub in read_file])
df10.head(5)
# Out:
# <class 'list'>
#   0     1     2        3             4          5            6   \
# 0     role  case  animacy  subject_word  verb_word  object_word
# 1  0     S   Nom                  اجلاس         ہو
# 2  1     S   Nom                   بورڈ         کر
# 3  2     O   Nom                                کر         اپیل
# 4  3     A   Acc                   بورڈ       کروا       اپیلیں
#
#                7                      8      9                       10  \
# 0  predicted_role          probability_A  layer  source_test_accuracy_A
# 1               A     0.7131028175354004     12      0.8652694610778443
# 2               A       0.98117595911026     12      0.8652694610778443
# 3               O  0.0006704188417643309     12      0.8652694610778443
# 4               A                    1.0     12      0.8652694610778443
#
#                          11
# 0  source_test_accuracy_O\n
# 1      0.8185880250223414\n
# 2      0.8185880250223414\n
# 3      0.8185880250223414\n
# ...

# %%
## basque basq

with open("results/latest_run/eu_bdt-ud_eu_bdt-ud-test.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df11 = pd.DataFrame([sub.split(",") for sub in read_file])
df11.head(5)
# Out:
# <class 'list'>
#   0     1     2        3             4          5            6   \
# 0     role  case  animacy  subject_word  verb_word  object_word
# 1  0     S   Par            hazkunderik   antzeman
# 2  1     S                     agintari   ziurtatu
# 3  2     O                                  onartu       eskari
# 4  3     S                     hegazkin       egon
#
#                7                      8      9                       10  \
# 0  predicted_role          probability_A  layer  source_test_accuracy_A
# 1               O  1.258978863916127e-05     12      0.8652694610778443
# 2               A     0.9999855756759644     12      0.8652694610778443
# 3               O  0.0006036483682692051     12      0.8652694610778443
# 4               A     0.9946459531784058     12      0.8652694610778443
#
#                          11
# 0  source_test_accuracy_O\n
# 1      0.8185880250223414\n
# 2      0.8185880250223414\n
# 3      0.8185880250223414\n
# ...

# %%
## urdu basq

with open("results/latest_run/ur_udtb-ud_eu_bdt-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df12 = pd.DataFrame([sub.split(",") for sub in read_file])
df12.head(5)
# Out:
# <class 'list'>
#   0     1     2        3             4          5            6   \
# 0     role  case  animacy  subject_word  verb_word  object_word
# 1  0     O   Abs     Inan                    jarri         masa
# 2  1     O                                    eman        herri
# 3  2     O                                    eman     laguntza
# 4  3     O                                 indartu     erakunde
#
#                7                      8      9                       10  \
# 0  predicted_role          probability_A  layer  source_test_accuracy_A
# 1               O  4.482377335079946e-06     12      0.8825757575757576
# 2               O   0.006065746769309044     12      0.8825757575757576
# 3               O  6.945942004676908e-06     12      0.8825757575757576
# 4               O   0.009737110696732998     12      0.8825757575757576
#
#                          11    12
# 0  source_test_accuracy_O\n  None
# 1                  0.8375\n  None
# ...

# %%
## urdu indo

with open("results/latest_run/ur_udtb-ud_id_gsd-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df13 = pd.DataFrame([sub.split(",") for sub in read_file])
df13.head(5)
# Out:
# <class 'list'>
#   0          1     2        3             4          5            6   \
# 0          role  case  animacy  subject_word  verb_word  object_word
# 1  0          S                     serangan    terjadi
# 2  1          O                                   bakar        rumah
# 3  2          O                               memenggal     penghuni
# 4  3  S-passive                 Perkembangan       ikut
#
#                7                   8      9                       10  \
# 0  predicted_role       probability_A  layer  source_test_accuracy_A
# 1               A   0.764359712600708     12      0.8825757575757576
# 2               A  0.9891718029975891     12      0.8825757575757576
# 3               A  0.9991132616996765     12      0.8825757575757576
# 4               A  0.5860880017280579     12      0.8825757575757576
#
#                          11
# 0  source_test_accuracy_O\n
# 1                  0.8375\n
# 2                  0.8375\n
# ...

# %%
## urdu mara

with open("results/latest_run/ur_udtb-ud_mr_ufal-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df14 = pd.DataFrame([sub.split(",") for sub in read_file])
df14.head(5)
# Out:
# <class 'list'>
#   0     1     2        3             4          5            6   \
# 0     role  case  animacy  subject_word  verb_word  object_word
# 1  0     A   Nom                   राजा       करित       त्याला
# 2  1     S   Nom                   राजा     म्हणणे
# 3  2     S   Nom             टक्केटोणपे       खाणे
# 4  3     A   Erg                 राजाने     सांगणे        विचार
#
#                7                      8      9                       10  \
# 0  predicted_role          probability_A  layer  source_test_accuracy_A
# 1               A     0.9999998807907104     12      0.8825757575757576
# 2               A     0.9766058921813965     12      0.8825757575757576
# 3               O  0.0001334912667516619     12      0.8825757575757576
# 4               A     0.9999974966049194     12      0.8825757575757576
#
#                          11
# 0  source_test_accuracy_O\n
# 1                  0.8375\n
# 2                  0.8375\n
# 3                  0.8375\n
# ...

# %%
## urdu ukr

with open("results/latest_run/ur_udtb-ud_uk_iu-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df15 = pd.DataFrame([sub.split(",") for sub in read_file])
df15.head(5)
# Out:
# <class 'list'>
#   0     1     2        3             4           5            6   \
# 0     role  case  animacy  subject_word   verb_word  object_word
# 1  0     S   Nom     Inan        фреска        бути
# 2  1     S   Nom     Anim     одновірці   зібратися
# 3  2     O   Acc     Inan                замазувати        стіну
# 4  3     O   Acc     Inan                   знищити   мальовидло
#
#                7                      8      9                       10  \
# 0  predicted_role          probability_A  layer  source_test_accuracy_A
# 1               A     0.9975090026855469     12      0.8825757575757576
# 2               O    0.12039223313331604     12      0.8825757575757576
# 3               O  0.0004212659550830722     12      0.8825757575757576
# 4               O     0.0581413209438324     12      0.8825757575757576
#
#                          11
# 0  source_test_accuracy_O\n
# 1                  0.8375\n
# 2                  0.8375\n
# 3                  0.8375\n
# ...

# %%
import pandas as pd

with open("results/latest_run/fr_gsd-ud_he_iahltwiki-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))


df16 = pd.DataFrame([sub.split(",") for sub in read_file])

df16
# Out:
# <class 'list'>
#           0          1     2        3             4          5            6   \
# 0                  role  case  animacy  subject_word  verb_word  object_word
# 1          0  S-passive                        מטופל      הוערך
# 2          1          A                        סיכום      היווה        הערכה
# 3          2          O                                   היווה        הערכה
# 4          3          S                        תוצאת       סייע
# ...      ...        ...   ...      ...           ...        ...          ...
# 25996  25995          A                        שירות        פתח      מהדורות
# 25997  25996          O                                     פתח      מהדורות
# 25998  25997          A                          רצף       ייצג          קוד
# 25999  25998          O                                    ייצג          קוד
# 26000  25999          S                        כתיבת        ארך
#
# ...
