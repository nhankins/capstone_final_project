# %%
#All output from classifier training

with open("entire_output_classifiers.rtf") as infile:
    for line in infile:
        print(line)
# Out:
# {\rtf1\ansi\ansicpg1252\cocoartf2639
#
# \cocoatextscaling0\cocoaplatform0{\fonttbl\f0\fswiss\fcharset0 Helvetica;\f1\fnil\fcharset77 KohinoorDevanagari-Regular;}
#
# {\colortbl;\red255\green255\blue255;}
#
# {\*\expandedcolortbl;;}
#
# \margl1440\margr1440\vieww24280\viewh14000\viewkind0
#
# \pard\tx720\tx1440\tx2160\tx2880\tx3600\tx4320\tx5040\tx5760\tx6480\tx7200\tx7920\tx8640\pardirnatural\partightenfactor0
#
#
#
# \f0\fs24 \cf0 (erg_nom) Nick deep-subjecthood-main % ./run_batch_0.sh                    \
#
# To use data.metrics please install scikit-learn. See https://scikit-learn.org/stable/index.html\
#
# args: Namespace(all_major_cases=False, average_embs=False, balance=True, erg_abs=False, nom_acc=False, only_ao=True, output_fn='latest_run/eu_bdt-ud_eu_bdt-ud-test.conllu_0', reeval_src_test=False, seed=0, test_lang_fn='language_data/UD_Basque-BDT-master/eu_bdt-ud-test.conllu', train_lang_base_path='language_data/UD_Basque-BDT-master/eu_bdt-ud')\
#
# Just set the seed to 0\
#
# ...

# %%
from io import open
from conllu import parse_incr

## Opens .conllu output for language classifier comparisons 

with open("results/latest_run/hi_hdtb-ud_eu_bdt-ud-train.conllu_0", "r", encoding="utf-8") as f:
    read_file = f.readlines()
    print(type(read_file))
# Out:
# <class 'list'>

# %%
import pandas as pd

df = pd.DataFrame([sub.split(",") for sub in read_file])
df.head(25)
# Out:
#     0      1     2        3             4          5            6   \
# 0        role  case  animacy  subject_word  verb_word  object_word
# 1    0      O   Abs     Inan                    jarri         masa
# 2    1      O                                    eman        herri
# 3    2      O                                    eman     laguntza
# 4    3      O                                 indartu     erakunde
# 5    4      O   Abs                         baieztatu  konpromisoa
# 6    5      A   Erg                    EBk  baieztatu  konpromisoa
# 7    6      O   Abs     Inan                bistaratu  zailtasunak
# 8    7      A                       Zidane      osatu        talde
# 9    8      O                                   osatu        talde
# 10   9      S                        anaia       esan
# 11  10      O   Abs     Inan                     erre       poemak
# 12  11  O-aux                                    edun    errespetu
# ...

# %%
df1 = df[[1,3,7]]
df1.head(25)

# for col in df.columns:
#     print(col)
# Out:
#         1        3               7
# 0    role  animacy  predicted_role
# 1       O     Inan               O
# 2       O                        O
# 3       O                        O
# 4       O                        O
# 5       O                        O
# 6       A                        A
# 7       O     Inan               A
# 8       A                        A
# 9       O                        A
# 10      S                        A
# 11      O     Inan               O
# 12  O-aux                        A
# 13  O-aux                        A
# 14      O                        O
# 15      O     Inan               O
# 16      O     Inan               A
# 17      O     Inan               O
# 18      O                        A
# 19      O     Inan               O
# 20      O                        A
# 21      S     Inan               O
# 22      O     Inan               A
# 23      O                        A
# 24      S     Anim               A

# %%
import pickle

cached_df = pd.read_pickle('cached_datasets/all_features_aso_exps_mr_ufal-ud-train_AO_balanced_2025.pkl')
cached_df_lst = list(cached_df)

filtered_df = cached_df_lst.pop(5)
#cached_df_lst
df = pd.DataFrame(cached_df_lst)
df_transposed = df.transpose()
df_transposed
#Up to 1344
# Out:
#                                                     0   \
# 0                                  [एक, होता, राजा, .]
# 1                         [त्याला, एक, मुलगा, होता, .]
# 2    [एकुलता, एक, मुलगा, म्हणून, राजा, -, राणी, त्य...
# 3         [परंतु, लाडामुळे, लाडा, मुळे, तो, बिघडला, .]
# 4    [राजा, मनात, म्हणाला, ,, ", याला, घालवून, द्या...
# ..                                                 ...
# 368  [त्यानेही, त्याने, ही, दोन, -, चार, कलमे, लावल...
# 369  [विहिरीच्या, विहिरी, च्या, कडेला, फुलझाडे, होत...
# 370  [पलीकडे, त्याचा, त्या, चा, लहानसा, गोठा, होता, .]
# 371  [भीमाचा, भीमा, चा, शब्द, ऐकताच, ऐकता, च, गोठ्य...
# 372  [खरोखरच, त्या, शेतावर, शेता, वर, भीमाचे, भीमा,...
#
#                                                     1   \
# 0                             [None, None, None, None]
# 1                       [None, None, None, None, None]
# 2    [None, None, None, None, Nom, None, None, None...
# 3           [None, None, None, None, None, None, None]
# ...

# %%
## Hidden States Data

import h5py as h5
    
# Read H5 file
f = h5.File("cached_bert_vectors/all_features_aso_exps_eu_bdt-ud-train_AO_balanced_2025.hdf5", "r")
# Get and print list of datasets within the H5 file
datasetNames = [n for n in f.items()]
for n in datasetNames:
	print(n)
# Out:
# ('0', <HDF5 dataset "0": shape (13, 13, 768), type "<f4">)
# ('1', <HDF5 dataset "1": shape (13, 62, 768), type "<f4">)
# ('10', <HDF5 dataset "10": shape (13, 20, 768), type "<f4">)
# ('100', <HDF5 dataset "100": shape (13, 28, 768), type "<f4">)
# ('1000', <HDF5 dataset "1000": shape (13, 14, 768), type "<f4">)
# ('1001', <HDF5 dataset "1001": shape (13, 47, 768), type "<f4">)
# ('1002', <HDF5 dataset "1002": shape (13, 14, 768), type "<f4">)
# ('1003', <HDF5 dataset "1003": shape (13, 35, 768), type "<f4">)
# ('1004', <HDF5 dataset "1004": shape (13, 32, 768), type "<f4">)
# ('1005', <HDF5 dataset "1005": shape (13, 26, 768), type "<f4">)
# ('1006', <HDF5 dataset "1006": shape (13, 16, 768), type "<f4">)
# ('1007', <HDF5 dataset "1007": shape (13, 17, 768), type "<f4">)
# ('1008', <HDF5 dataset "1008": shape (13, 13, 768), type "<f4">)
# ('1009', <HDF5 dataset "1009": shape (13, 13, 768), type "<f4">)
# ('101', <HDF5 dataset "101": shape (13, 18, 768), type "<f4">)
# ...

# %%
with open("classifiers/aso_eu_bdt-ud_0_ao_balanced_0_exproles", "rb") as fi:
    read_layer = fi.readlines()
    print(type(read_layer))
# Out:
# <class 'list'>

# %%
## Opens each layer

import pickle

cached_layer = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_0_exproles')
cached_layer_0 = list(cached_layer)

# %%
print(cached_layer_0[3])
# Out:
# {'A': 0.7245508982035929, 'O': 0.6550491510277033}

# %%
cached_layer7 = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_7_exproles')
cached_layer_7 = list(cached_layer7)
print(cached_layer_7)
# Out:
# [_classifier(
#   (main): Sequential(
#     (0): Linear(in_features=768, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=2, bias=True)
#     (3): Dropout(p=0.1, inplace=False)
#   )
# ), ['A', 'O', 'S', 'S-aux'], {'A': 0, 'O': 1, 'S': 2, 'S-aux': 3}, {'A': 0.8952095808383234, 'O': 0.872207327971403}, defaultdict(<class 'collections.Counter'>, {'O': Counter({'Abs': 2087, None: 912, 'Dat': 329, 'Par': 144, 'Erg': 11, 'Gen': 7, 'Loc': 4, 'All': 2, 'Abl': 2, 'Ine': 1}), 'A': Counter({'Erg': 752, None: 201, 'Abs': 57, 'Ine': 2, 'Loc': 1})})]

# %%
#Prefix Key: 0 - Basque, 1 - Hindi, 2 - Urdu

import pickle 
import pandas as pd

print(f'Basque Classifier Layers')

cached_layer = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_0_exproles')
cached_layer_00 = list(cached_layer)
print(f'Layer 0: {cached_layer_00[3]}')

cached_layer01 = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_1_exproles')
cached_layer_01 = list(cached_layer01)
print(f'Layer 1: {cached_layer_01[3]}')

cached_layer02 = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_2_exproles')
cached_layer_02 = list(cached_layer02)
print(f'Layer 2: {cached_layer_02[3]}')

cached_layer03 = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_3_exproles')
cached_layer_03 = list(cached_layer03)
print(f'Layer 3: {cached_layer_03[3]}')

cached_layer04 = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_4_exproles')
cached_layer_04 = list(cached_layer04)
print(f'Layer 4: {cached_layer_04[3]}')

cached_layer05 = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_5_exproles')
cached_layer_05 = list(cached_layer05)
print(f'Layer 5: {cached_layer_05[3]}')

cached_layer06 = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_6_exproles')
cached_layer_06 = list(cached_layer06)
print(f'Layer 6: {cached_layer_06[3]}')

cached_layer07 = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_7_exproles')
cached_layer_07 = list(cached_layer07)
print(f'Layer 7: {cached_layer_07[3]}')

cached_layer08 = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_8_exproles')
cached_layer_08 = list(cached_layer08)
print(f'Layer 8: {cached_layer_08[3]}')

cached_layer09 = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_9_exproles')
cached_layer_09 = list(cached_layer09)
print(f'Layer 9: {cached_layer_09[3]}')

cached_layer010 = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_10_exproles')
cached_layer_010 = list(cached_layer010)
print(f'Layer 10: {cached_layer_010[3]}')

cached_layer011 = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_11_exproles')
cached_layer_011 = list(cached_layer011)
print(f'Layer 11: {cached_layer_011[3]}')

cached_layer012 = pd.read_pickle('classifiers/aso_eu_bdt-ud_0_ao_balanced_12_exproles')
cached_layer_012 = list(cached_layer012)
print(f'Layer 12: {cached_layer_012[3]}')

print(f'............')

print(f'Hindi Classifier Layers')

cached_layer10 = pd.read_pickle('classifiers/aso_hi_hdtb-ud_0_ao_balanced_0_exproles')
cached_layer_10 = list(cached_layer10)
print(f'Layer 0: {cached_layer_10[3]}')

cached_layer11 = pd.read_pickle('classifiers/aso_hi_hdtb-ud_0_ao_balanced_1_exproles')
cached_layer_11 = list(cached_layer11)
print(f'Layer 1: {cached_layer_11[3]}')

cached_layer12 = pd.read_pickle('classifiers/aso_hi_hdtb-ud_0_ao_balanced_2_exproles')
cached_layer_12 = list(cached_layer12)
print(f'Layer 2: {cached_layer_12[3]}')

cached_layer13 = pd.read_pickle('classifiers/aso_hi_hdtb-ud_0_ao_balanced_3_exproles')
cached_layer_13 = list(cached_layer13)
print(f'Layer 3: {cached_layer_13[3]}')

cached_layer14 = pd.read_pickle('classifiers/aso_hi_hdtb-ud_0_ao_balanced_4_exproles')
cached_layer_14 = list(cached_layer14)
print(f'Layer 4: {cached_layer_14[3]}')

cached_layer15 = pd.read_pickle('classifiers/aso_hi_hdtb-ud_0_ao_balanced_5_exproles')
cached_layer_15 = list(cached_layer15)
print(f'Layer 5: {cached_layer_15[3]}')

cached_layer16 = pd.read_pickle('classifiers/aso_hi_hdtb-ud_0_ao_balanced_6_exproles')
cached_layer_16 = list(cached_layer16)
print(f'Layer 6: {cached_layer_16[3]}')

cached_layer17 = pd.read_pickle('classifiers/aso_hi_hdtb-ud_0_ao_balanced_7_exproles')
cached_layer_17 = list(cached_layer17)
print(f'Layer 7: {cached_layer_17[3]}')

cached_layer18 = pd.read_pickle('classifiers/aso_hi_hdtb-ud_0_ao_balanced_8_exproles')
cached_layer_18 = list(cached_layer18)
print(f'Layer 8: {cached_layer_18[3]}')

cached_layer19 = pd.read_pickle('classifiers/aso_hi_hdtb-ud_0_ao_balanced_9_exproles')
cached_layer_19 = list(cached_layer19)
print(f'Layer 9: {cached_layer_19[3]}')

cached_layer110 = pd.read_pickle('classifiers/aso_hi_hdtb-ud_0_ao_balanced_10_exproles')
cached_layer_110 = list(cached_layer110)
print(f'Layer 10: {cached_layer_110[3]}')

cached_layer111 = pd.read_pickle('classifiers/aso_hi_hdtb-ud_0_ao_balanced_11_exproles')
cached_layer_111 = list(cached_layer111)
print(f'Layer 11: {cached_layer_111[3]}')

cached_layer112 = pd.read_pickle('classifiers/aso_hi_hdtb-ud_0_ao_balanced_12_exproles')
cached_layer_112 = list(cached_layer112)
print(f'Layer 12: {cached_layer_112[3]}')

print(f'............')

print(f'Urdu Classifier Layers')

cached_layer20 = pd.read_pickle('classifiers/aso_ur_udtb-ud_0_ao_balanced_0_exproles')
cached_layer_20 = list(cached_layer20)
print(f'Layer 0: {cached_layer_20[3]}')

cached_layer21 = pd.read_pickle('classifiers/aso_ur_udtb-ud_0_ao_balanced_1_exproles')
cached_layer_21 = list(cached_layer21)
print(f'Layer 1: {cached_layer_21[3]}')

cached_layer22 = pd.read_pickle('classifiers/aso_ur_udtb-ud_0_ao_balanced_2_exproles')
cached_layer_22 = list(cached_layer22)
print(f'Layer 2: {cached_layer_22[3]}')

cached_layer23 = pd.read_pickle('classifiers/aso_ur_udtb-ud_0_ao_balanced_3_exproles')
cached_layer_23 = list(cached_layer23)
print(f'Layer 3: {cached_layer_23[3]}')

cached_layer24 = pd.read_pickle('classifiers/aso_ur_udtb-ud_0_ao_balanced_4_exproles')
cached_layer_24 = list(cached_layer24)
print(f'Layer 4: {cached_layer_24[3]}')

cached_layer25 = pd.read_pickle('classifiers/aso_ur_udtb-ud_0_ao_balanced_5_exproles')
cached_layer_25 = list(cached_layer25)
print(f'Layer 5: {cached_layer_25[3]}')

cached_layer26 = pd.read_pickle('classifiers/aso_ur_udtb-ud_0_ao_balanced_6_exproles')
cached_layer_26 = list(cached_layer26)
print(f'Layer 6: {cached_layer_26[3]}')

cached_layer27 = pd.read_pickle('classifiers/aso_ur_udtb-ud_0_ao_balanced_7_exproles')
cached_layer_27 = list(cached_layer27)
print(f'Layer 7: {cached_layer_27[3]}')

cached_layer28 = pd.read_pickle('classifiers/aso_ur_udtb-ud_0_ao_balanced_8_exproles')
cached_layer_28 = list(cached_layer28)
print(f'Layer 8: {cached_layer_28[3]}')

cached_layer29 = pd.read_pickle('classifiers/aso_ur_udtb-ud_0_ao_balanced_9_exproles')
cached_layer_29 = list(cached_layer29)
print(f'Layer 9: {cached_layer_29[3]}')

cached_layer210 = pd.read_pickle('classifiers/aso_ur_udtb-ud_0_ao_balanced_10_exproles')
cached_layer_210 = list(cached_layer210)
print(f'Layer 10: {cached_layer_210[3]}')

cached_layer211 = pd.read_pickle('classifiers/aso_ur_udtb-ud_0_ao_balanced_11_exproles')
cached_layer_211 = list(cached_layer211)
print(f'Layer 11: {cached_layer_211[3]}')

cached_layer212 = pd.read_pickle('classifiers/aso_ur_udtb-ud_0_ao_balanced_12_exproles')
cached_layer_212 = list(cached_layer212)
print(f'Layer 12: {cached_layer_212[3]}')
# Out:
# Basque Classifier Layers
# Layer 0: {'A': 0.7245508982035929, 'O': 0.6550491510277033}
# Layer 1: {'A': 0.7005988023952096, 'O': 0.6943699731903485}
# Layer 2: {'A': 0.7035928143712575, 'O': 0.7649687220732797}
# Layer 3: {'A': 0.7604790419161677, 'O': 0.7765862377122431}
# Layer 4: {'A': 0.8203592814371258, 'O': 0.7265415549597856}
# Layer 5: {'A': 0.7934131736526946, 'O': 0.80875781948168}
# Layer 6: {'A': 0.8712574850299402, 'O': 0.8632707774798928}
# Layer 7: {'A': 0.8952095808383234, 'O': 0.872207327971403}
# Layer 8: {'A': 0.8922155688622755, 'O': 0.870420017873101}
# Layer 9: {'A': 0.8982035928143712, 'O': 0.8650580875781948}
# Layer 10: {'A': 0.8922155688622755, 'O': 0.8552278820375335}
# Layer 11: {'A': 0.8502994011976048, 'O': 0.8659517426273459}
# Layer 12: {'A': 0.8652694610778443, 'O': 0.8185880250223414}
# ............
# Hindi Classifier Layers
# Layer 0: {'A': 0.7065637065637066, 'O': 0.641491395793499}
# Layer 1: {'A': 0.7915057915057915, 'O': 0.5898661567877629}
# ...

# %%
# a_o_urdu_12 = cached_layer_212[3]
# print(eu0)

# %%
import matplotlib.pyplot as plt
import numpy as np

#layer 1 test
eu0 = cached_layer_00[3]
hi0 = cached_layer_10[3]
ur0 = cached_layer_20[3]

eu1 = cached_layer_01[3]
hi1 = cached_layer_11[3]
ur1 = cached_layer_21[3]

eu_data = list(eu0.values())
hi_data = list(hi0.values())
ur_data = list(ur0.values())

eu1_data = list(eu1.values())
hi1_data = list(hi1.values())
ur1_data = list(ur1.values())

eu2 = cached_layer_02[3]
hi2 = cached_layer_12[3]
ur2 = cached_layer_22[3]

eu2_data = list(eu2.values())
hi2_data = list(hi2.values())
ur2_data = list(ur2.values())


# eu = np.array(eu_data)
# hi = np.array(hi_data)
# ur = np.array(ur_data)

#x = np.array([eu,hi,ur])

# fig, ax = plt.subplots()
# ax.plot(eu)
# ax.plot(hi)
# ax.plot(ur)

# ax.set_title('A:O mBERT Layers')
# plt.show()

# %%
import matplotlib.pyplot as plt

#print(eu_data)
#print(hi_data)
#print(ur_data)

layer_0 = [eu_data,hi_data,ur_data]
#print(layer_0)

#columns=['Basque','Hindi','Urdu']

#### Separates x and y into two rows when they should 
#### be in the same cell

df_layer_0 = pd.DataFrame(index=[0], columns=['Basque','Hindi', 'Urdu'])
df_layer_0.loc[0,'Basque'] = eu_data
df_layer_0.loc[0,'Hindi'] = hi_data
df_layer_0.loc[0,'Urdu'] = ur_data

df_layers = df_layer_0
df_layers.loc[1,'Basque'] = eu1_data
df_layers.loc[1,'Hindi'] = hi1_data
df_layers.loc[1,'Urdu'] = ur1_data

df_layers.loc[2,'Basque'] = eu2_data
df_layers.loc[2,'Hindi'] = hi2_data
df_layers.loc[2,'Urdu'] = ur2_data

df_plot = df_layers

### Adding the other layers 

eu3 = cached_layer_03[3]
hi3 = cached_layer_13[3]
ur3 = cached_layer_23[3]

eu3_data = list(eu3.values())
hi3_data = list(hi3.values())
ur3_data = list(ur3.values())

df_layers.loc[3,'Basque'] = eu3_data
df_layers.loc[3,'Hindi'] = hi3_data
df_layers.loc[3,'Urdu'] = ur3_data

#layer 4

eu4 = cached_layer_04[3]
hi4 = cached_layer_14[3]
ur4 = cached_layer_24[3]
eu4_data = list(eu4.values())
hi4_data = list(hi4.values())
ur4_data = list(ur4.values())

df_layers.loc[4,'Basque'] = eu4_data
df_layers.loc[4,'Hindi'] = hi4_data
df_layers.loc[4,'Urdu'] = ur4_data

# layer 5

eu5 = cached_layer_05[3]
hi5 = cached_layer_15[3]
ur5 = cached_layer_25[3]
eu5_data = list(eu5.values())
hi5_data = list(hi5.values())
ur5_data = list(ur5.values())

df_layers.loc[5,'Basque'] = eu5_data
df_layers.loc[5,'Hindi'] = hi5_data
df_layers.loc[5,'Urdu'] = ur5_data

#layer 6

eu6 = cached_layer_06[3]
hi6 = cached_layer_16[3]
ur6 = cached_layer_26[3]
eu6_data = list(eu6.values())
hi6_data = list(hi6.values())
ur6_data = list(ur6.values())

df_layers.loc[6,'Basque'] = eu6_data
df_layers.loc[6,'Hindi'] = hi6_data
df_layers.loc[6,'Urdu'] = ur6_data

# layer 7

eu7 = cached_layer_07[3]
hi7 = cached_layer_17[3]
ur7 = cached_layer_27[3]
eu7_data = list(eu7.values())
hi7_data = list(hi7.values())
ur7_data = list(ur7.values())

df_layers.loc[7,'Basque'] = eu7_data
df_layers.loc[7,'Hindi'] = hi7_data
df_layers.loc[7,'Urdu'] = ur7_data

#layer 8

eu8 = cached_layer_08[3]
hi8 = cached_layer_18[3]
ur8 = cached_layer_28[3]
eu8_data = list(eu8.values())
hi8_data = list(hi8.values())
ur8_data = list(ur8.values())

df_layers.loc[8,'Basque'] = eu8_data
df_layers.loc[8,'Hindi'] = hi8_data
df_layers.loc[8,'Urdu'] = ur8_data

#layer 9

eu9 = cached_layer_09[3]
hi9 = cached_layer_19[3]
ur9 = cached_layer_29[3]
eu9_data = list(eu9.values())
hi9_data = list(hi9.values())
ur9_data = list(ur9.values())

df_layers.loc[9,'Basque'] = eu9_data
df_layers.loc[9,'Hindi'] = hi9_data
df_layers.loc[9,'Urdu'] = ur9_data

#layer 10

eu10 = cached_layer_010[3]
hi10 = cached_layer_110[3]
ur10 = cached_layer_210[3]
eu10_data = list(eu10.values())
hi10_data = list(hi10.values())
ur10_data = list(ur10.values())

df_layers.loc[10,'Basque'] = eu10_data
df_layers.loc[10,'Hindi'] = hi10_data
df_layers.loc[10,'Urdu'] = ur10_data


#layer 11

eu11 = cached_layer_011[3]
hi11 = cached_layer_111[3]
ur11 = cached_layer_211[3]
eu11_data = list(eu11.values())
hi11_data = list(hi11.values())
ur11_data = list(ur11.values())

df_layers.loc[11,'Basque'] = eu11_data
df_layers.loc[11,'Hindi'] = hi11_data
df_layers.loc[11,'Urdu'] = ur11_data

#layer 12

eu12 = cached_layer_012[3]
hi12 = cached_layer_112[3]
ur12 = cached_layer_212[3]
eu12_data = list(eu12.values())
hi12_data = list(hi12.values())
ur12_data = list(ur12.values())

df_layers.loc[12,'Basque'] = eu12_data
df_layers.loc[12,'Hindi'] = hi12_data
df_layers.loc[12,'Urdu'] = ur12_data

print(type(eu12_data))



#plt.plot(df_plot.iloc[0]['Basque'], df_plot.iloc[0]['Hindi'], df_plot.iloc[0]['Urdu'])



# df_layer_plt = df_layers[['Basque','Hindi','Urdu']].unstack().apply(pd.Series)
# df_layer_plt.plt.scatter()
# Out:
# <class 'list'>

# %%
df_layers['Basque'].dtype
# Out:
# dtype('O')

# %%
df_layers.dtypes
# Out:
# Basque    object
# Hindi     object
# Urdu      object
# dtype: object

# %%
df_layers[['Basque','Hindi','Urdu']].applymap(lambda x: x[0]).plot.bar(rot=0, color=list('brg'),figsize=(12, 7))
# Out:
# <Axes: >

# %%
import pickle

cached_df_germ = pd.read_pickle('cached_datasets/all_features_aso_exps_de_gsd-ud-train_AO_balanced_2025.pkl')
cached_df_lst_germ = list(cached_df_germ)
#print(cached_df_lst_germ)

filtered_df_germ = cached_df_lst_germ.pop(5)

df_germ = pd.DataFrame(cached_df_lst_germ)
df_transposed_germ = df_germ.transpose()
df_transposed_germ
# Out:
#                                                      0   \
# 0     [Sehr, gute, Beratung, ,, schnelle, Behebung, ...
# 1     [Die, Kosten, sind, definitiv, auch, im, in, d...
# 2               [Nette, Gespräche, ,, klasse, Ergebnis]
# 3     [Ich, bin, seit, längerer, Zeit, zur, zu, der,...
# 4     [Ob, bei, der, Terminvergabe, ,, den, Behandlu...
# ...                                                 ...
# 4728  [Außerdem, sind, viele, dieser, Tendenzen, wie...
# 4729  [Seit, 1999, war, er, Chief, Administrative, O...
# 4730  [Suck, ist, ein, kinderreicher, Holzknecht, un...
# 4731  [Diese, Expedition, fand, einige, Bäume, ,, di...
# 4732  [Das, Album, erhielt, größtenteils, wohlwollen...
#
#                                                      1   \
# 0     [None, None, None, None, None, None, None, Non...
# 1     [None, Nom, None, None, None, None, None, None...
# 2                        [None, None, None, None, None]
# 3     [None, None, None, None, None, None, None, Non...
# ...
